# %%
import pymongo
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st
import plotly.express as px
import numpy as np

# %%
#Mongodb Atlas Connection details
mongodb_username="Revathy"
mongodb_password="guvi2024"
mongodb_cluster="Cluster0"
mongodb_database="sample_airbnb"
mongodb_collection="listingsAndReviews"

# %%
#Mongodb connection
client = pymongo.MongoClient("mongodb://Revathy:guvi2024@ac-5n8fsfk-shard-00-00.berjwr1.mongodb.net:27017,ac-5n8fsfk-shard-00-01.berjwr1.mongodb.net:27017,ac-5n8fsfk-shard-00-02.berjwr1.mongodb.net:27017/?ssl=true&replicaSet=atlas-11ihco-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")
db = client[mongodb_database]
coll = db[mongodb_collection]

# %%
coll
# Out:
# Collection(Database(MongoClient(host=['ac-5n8fsfk-shard-00-02.berjwr1.mongodb.net:27017', 'ac-5n8fsfk-shard-00-00.berjwr1.mongodb.net:27017', 'ac-5n8fsfk-shard-00-01.berjwr1.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-11ihco-shard-0', authsource='admin', retrywrites=True, w='majority', appname='Cluster0', tls=True), 'sample_airbnb'), 'listingsAndReviews')

# %%
#Retrieving dataset from Mongodb and converting it into DataFrame
dataset=[]
for i in coll.find():
    data={
        "ID": i['_id'],
        "Listing_URL": i['listing_url'],
        "Name": i['name'],
        "Description": i['description'],
        "Neighborhood_overview": i['neighborhood_overview'],
        "House_Rules": i.get('house_rules'),
        "Property Type": i ['property_type'],
        "Room Type": i['room_type'],
        "Bed Type": i ['bed_type'],
        "Minimum Nights": int(i['minimum_nights']),
        "Maximum Nights": int(i['maximum_nights']),
        "Cancellation_policy": i['cancellation_policy'],
        "Last_Scraped": i['last_scraped'],
        "Calendar Last Scraped": i['calendar_last_scraped'],
        "Number of Review": i['number_of_reviews'],
        "Amenities": i['amenities'],
        "Price": i['price'],
        "Security Deposit": i.get('security_deposit'),
        "Host ID": i['host']['host_id'],
        "Host Name": i['host']['host_name'],
        "Street": i['address']['street'],
        "Country": i['address']['country'],
        "Country code": i['address']['country_code'],
        "Longitude": i['address']['location']['coordinates'][0],
        "Latitude": i['address']['location']['coordinates'][1],
        "Availability": i['availability']['availability_365'],
        "Review Scores": i['review_scores']
    }
    dataset.append(data)

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#             ID                            Listing_URL  \
# 0     10082422  https://www.airbnb.com/rooms/10082422
# 1     10021707  https://www.airbnb.com/rooms/10021707
# 2     10059244  https://www.airbnb.com/rooms/10059244
# 3     10009999  https://www.airbnb.com/rooms/10009999
# 4     10069642  https://www.airbnb.com/rooms/10069642
# ...        ...                                    ...
# 5550   9714401   https://www.airbnb.com/rooms/9714401
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9848837   https://www.airbnb.com/rooms/9848837
# 5553   9867316   https://www.airbnb.com/rooms/9867316
# 5554   9987200   https://www.airbnb.com/rooms/9987200
#
#                                                   Name  \
# 0                        Nice room in Barcelona Center
# 1                             Private Room in Bushwick
# 2     Ligne verte - à 15 min de métro du centre ville.
# 3                         Horto flat with small garden
# ...

# %%
columns=df.columns
print(columns)
# Out:
# Index(['ID', 'Listing_URL', 'Name', 'Description', 'Neighborhood_overview',
#        'House_Rules', 'Property Type', 'Room Type', 'Bed Type',
#        'Minimum Nights', 'Maximum Nights', 'Cancellation_policy',
#        'Last_Scraped', 'Calendar Last Scraped', 'Number of Review',
#        'Amenities', 'Price', 'Security Deposit', 'Host ID', 'Host Name',
#        'Street', 'Country', 'Country code', 'Longitude', 'Latitude',
#        'Availability', 'Review Scores'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# ID                          0
# Listing_URL                 0
# Name                        0
# Description                 0
# Neighborhood_overview       0
# House_Rules                 0
# Property Type               0
# Room Type                   0
# Bed Type                    0
# Minimum Nights              0
# Maximum Nights              0
# Cancellation_policy         0
# Last_Scraped                0
# Calendar Last Scraped       0
# Number of Review            0
# Amenities                   0
# Price                       0
# Security Deposit         2084
# Host ID                     0
# Host Name                   0
# Street                      0
# Country                     0
# Country code                0
# Longitude                   0
# Latitude                    0
# Availability                0
# Review Scores               0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                               object
# Listing_URL                      object
# Name                             object
# Description                      object
# Neighborhood_overview            object
# House_Rules                      object
# Property Type                    object
# Room Type                        object
# Bed Type                         object
# Minimum Nights                    int64
# Maximum Nights                    int64
# Cancellation_policy              object
# Last_Scraped             datetime64[ns]
# Calendar Last Scraped    datetime64[ns]
# Number of Review                  int64
# Amenities                        object
# Price                            object
# Security Deposit                 object
# Host ID                          object
# Host Name                        object
# Street                           object
# Country                          object
# Country code                     object
# ...

# %%
import numpy as np
df['Security Deposit'] = df['Security Deposit'][~df['Security Deposit'].isna()].astype(str).astype(float)

# %%
df['Price']=df['Price'].astype(str).astype(float)
df["Host ID"]=df['Host ID'].astype(str).astype(float)

# %%
# Replace any non-integer values with NaN
df['Review Scores'] = pd.to_numeric(df['Review Scores'], errors='coerce')

# Handle missing values (NaN) according to your preference, for example, by filling them with a specific value like 0:
df['Review Scores'].fillna(0, inplace=True)

# Now, convert the column to integer type
df['Review Scores'] = df['Review Scores'].astype(int)
# Out:
# C:\Users\Revathy\AppData\Local\Temp\ipykernel_12264\117719785.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Review Scores'].fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     5555 non-null   object
#  1   Listing_URL            5555 non-null   object
#  2   Name                   5555 non-null   object
#  3   Description            5555 non-null   object
#  4   Neighborhood_overview  5555 non-null   object
#  5   House_Rules            5555 non-null   object
#  6   Property Type          5555 non-null   object
#  7   Room Type              5555 non-null   object
#  8   Bed Type               5555 non-null   object
#  9   Minimum Nights         5555 non-null   int64
#  10  Maximum Nights         5555 non-null   int64
#  11  Cancellation_policy    5555 non-null   object
#  12  Last_Scraped           5555 non-null   datetime64[ns]
#  13  Calendar Last Scraped  5555 non-null   datetime64[ns]
# ...

# %%
df['Security Deposit']=df['Security Deposit'].fillna(df['Security Deposit'].median())

# %%
df.isna().sum()
# Out:
# ID                       0
# Listing_URL              0
# Name                     0
# Description              0
# Neighborhood_overview    0
# House_Rules              0
# Property Type            0
# Room Type                0
# Bed Type                 0
# Minimum Nights           0
# Maximum Nights           0
# Cancellation_policy      0
# Last_Scraped             0
# Calendar Last Scraped    0
# Number of Review         0
# Amenities                0
# Price                    0
# Security Deposit         0
# Host ID                  0
# Host Name                0
# Street                   0
# Country                  0
# Country code             0
# Longitude                0
# Latitude                 0
# Availability             0
# Review Scores            0
# dtype: int64

# %%
spaces=df.isin(['']).sum()
# Out:
# C:\Users\Revathy\AppData\Local\Temp\ipykernel_12264\1245140472.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   spaces=df.isin(['']).sum()

# %%
spaces
# Out:
# ID                          0
# Listing_URL                 0
# Name                        8
# Description                95
# Neighborhood_overview    2241
# House_Rules              2285
# Property Type               0
# Room Type                   0
# Bed Type                    0
# Minimum Nights              0
# Maximum Nights              0
# Cancellation_policy         0
# Last_Scraped                0
# Calendar Last Scraped       0
# Number of Review            0
# Amenities                   0
# Price                       0
# Security Deposit            0
# Host ID                     0
# Host Name                   0
# Street                      0
# Country                     0
# Country code                0
# Longitude                   0
# Latitude                    0
# Availability                0
# Review Scores               0
# dtype: int64

# %%
df.Description.replace(to_replace='',value="No description provided",inplace=True)
df.House_Rules.replace(to_replace='',value="No House Rules provided",inplace=True)
df.Neighborhood_overview.replace(to_replace='',value="No Neighbourhood overview provided",inplace=True)
df.Name.replace(to_replace='',value="No Name provided",inplace=True)
df.Amenities.replace(to_replace='',value="No Amenities provided",inplace=True)
# Out:
# C:\Users\Revathy\AppData\Local\Temp\ipykernel_12264\1549633327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Description.replace(to_replace='',value="No description provided",inplace=True)
# C:\Users\Revathy\AppData\Local\Temp\ipykernel_12264\1549633327.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
spaces=df.isin(['']).sum()
# Out:
# C:\Users\Revathy\AppData\Local\Temp\ipykernel_12264\1245140472.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   spaces=df.isin(['']).sum()

# %%
spaces
# Out:
# ID                       0
# Listing_URL              0
# Name                     0
# Description              0
# Neighborhood_overview    0
# House_Rules              0
# Property Type            0
# Room Type                0
# Bed Type                 0
# Minimum Nights           0
# Maximum Nights           0
# Cancellation_policy      0
# Last_Scraped             0
# Calendar Last Scraped    0
# Number of Review         0
# Amenities                0
# Price                    0
# Security Deposit         0
# Host ID                  0
# Host Name                0
# Street                   0
# Country                  0
# Country code             0
# Longitude                0
# Latitude                 0
# Availability             0
# Review Scores            0
# dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame

# Iterate over each column
for column in df.columns:
    # Check if any value in the column is of type list
    if any(isinstance(value, list) for value in df[column]):
        print(f"Column '{column}' contains lists.")

          # Convert lists to strings
        df[column] = df[column].apply(lambda x: ','.join(x) if isinstance(x, list) else x)
        print("Lists converted to strings")
# Out:
# Column 'Amenities' contains lists.
# Lists converted to strings

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#             ID                            Listing_URL  \
# 0     10082422  https://www.airbnb.com/rooms/10082422
# 1     10021707  https://www.airbnb.com/rooms/10021707
# 2     10059244  https://www.airbnb.com/rooms/10059244
# 3     10009999  https://www.airbnb.com/rooms/10009999
# 4     10069642  https://www.airbnb.com/rooms/10069642
# ...        ...                                    ...
# 5550   9714401   https://www.airbnb.com/rooms/9714401
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9848837   https://www.airbnb.com/rooms/9848837
# 5553   9867316   https://www.airbnb.com/rooms/9867316
# 5554   9987200   https://www.airbnb.com/rooms/9987200
#
#                                                   Name  \
# 0                        Nice room in Barcelona Center
# 1                             Private Room in Bushwick
# 2     Ligne verte - à 15 min de métro du centre ville.
# 3                         Horto flat with small garden
# ...

# %%
df.to_csv("Airbnb.csv")

# %%
df.to_excel("Airbnb_data.excel")
